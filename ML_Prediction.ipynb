# %%
import pandas as pd

# %%
player_stats = pd.read_csv('full_stats.csv',index_col=[0])
player_stats
# Out:
#                Player Pos  Age   G  GS    MP   FG   FGA    FG%   3P  ...  \
# 0          A.C. Green  PF   26  82  82  33.0  4.7   9.8  0.478  0.2  ...
# 1         Byron Scott  SG   28  77  77  33.7  6.1  13.1  0.470  1.2  ...
# 2        James Worthy  SF   28  80  80  37.0  8.9  16.2  0.548  0.2  ...
# 3       Jawann Oldham   C   32   6   0   7.5  0.5   1.0  0.500  0.0  ...
# 4         Jay Vincent  SF   30  41   6  11.2  2.1   4.5  0.470  0.0  ...
# ...               ...  ..  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 14466   Spencer Hawes  PF   28  54   1  14.8  2.5   5.1  0.484  0.5  ...
# 14467     Steve Novak  PF   33   8   0   2.8  0.3   0.9  0.286  0.1  ...
# 14468  Terrence Jones  PF   25  54  12  23.5  4.3   9.1  0.470  0.4  ...
# 14469      Thon Maker   C   19  57  34   9.9  1.5   3.2  0.459  0.5  ...
# 14470      Tony Snell  SG   25  80  80  29.2  3.1   6.8  0.455  1.8  ...
#
#        Pts Max  Share                Team   W   L   W/L%   GB   PS/G   PA/G  \
# ...

# %%
player_stats[player_stats['Player']=='Stephen Curry']
# Out:
#              Player Pos  Age   G  GS    MP    FG   FGA    FG%   3P  ...  \
# 1530  Stephen Curry  PG   22  74  74  33.6   6.8  14.2  0.480  2.0  ...
# 3689  Stephen Curry  PG   31   5   5  27.8   6.6  16.4  0.402  2.4  ...
# 3707  Stephen Curry  PG   32  63  63  34.2  10.4  21.7  0.482  5.3  ...
# 4235  Stephen Curry  PG   30  69  69  33.8   9.2  19.4  0.472  5.1  ...
# 5680  Stephen Curry  PG   27  79  79  34.2  10.2  20.2  0.504  5.1  ...
# 5695  Stephen Curry  PG   28  79  79  33.4   8.5  18.3  0.468  4.1  ...
# 6152  Stephen Curry  PG   25  78  78  36.5   8.4  17.7  0.471  3.3  ...
# 6168  Stephen Curry  PG   26  80  80  32.7   8.2  16.8  0.487  3.6  ...
# 6184  Stephen Curry  PG   29  51  51  32.0   8.4  16.9  0.495  4.2  ...
# 6823  Stephen Curry  PG   24  78  78  38.2   8.0  17.8  0.451  3.5  ...
# 7357  Stephen Curry  PG   21  80  77  36.2   6.6  14.3  0.462  2.1  ...
# 7375  Stephen Curry  PG   23  26  23  28.2   5.6  11.4  0.490  2.1  ...
#
# ...

# %%
'''
Fields with missing value 
FG%: Field goal percentage, 
3P%: three point field goal percentage 
2P%: two point field goal  percentage 
eFG%: effective field goal percentage is a statisitcs that ajusts field goal percentage to acount fothe fact that three point field 
goals count for three points while fields goals only count for two points. 
FT%: free throw field gola percentage
'''

pd.isnull(player_stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          51
# 3P            0
# 3PA           0
# 3P%        2102
# 2P            0
# 2PA           0
# 2P%          85
# eFG%         51
# FT            0
# FTA           0
# FT%         468
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
player_stats[pd.isnull(player_stats["3P%"])][['Player','3PA']]
# Out:
#                  Player  3PA
# 3         Jawann Oldham  0.0
# 7         Mark McNamara  0.0
# 8           Mel McCants  0.0
# 10      Mychal Thompson  0.0
# 16       Elden Campbell  0.0
# ...                 ...  ...
# 14440    Evan Eschmeyer  0.0
# 14441  Gheorghe Mureșan  0.0
# 14443     Jim McIlvaine  0.0
# 14449  Mark Hendrickson  0.0
# 14450      Michael Cage  0.0
#
# [2102 rows x 2 columns]

# %%
player_stats=player_stats.fillna(0)

# %%
pd.isnull(player_stats).sum()
# Out:
# Player     0
# Pos        0
# Age        0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%        0
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%        0
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# Year       0
# Pts Won    0
# Pts Max    0
# Share      0
# Team       0
# W          0
# L          0
# W/L%       0
# GB         0
# PS/G       0
# PA/G       0
# SRS        0
# dtype: int64

# %%
player_stats['Year'].value_counts()
# Out:
# 2021    540
# 2018    540
# 2019    530
# 2020    529
# 2015    492
# 2017    486
# 2014    480
# 2012    478
# 2016    476
# 2013    467
# 2005    464
# 2007    458
# 2006    458
# 2011    452
# 2008    450
# 2009    443
# 2004    442
# 2010    442
# 2001    441
# 1997    441
# 2002    440
# 1999    440
# 1998    439
# 2000    439
# 1996    428
# 2003    428
# 1995    405
# 1994    403
# 1993    390
# 1992    386
# 1991    385
# 1990    379
# Name: Year, dtype: int64

# %%
player_stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
       'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %%
len(predictors)
# Out:
# 31

# %%
train=player_stats[~(player_stats['Year']==2021)]
test=player_stats[player_stats['Year']==2021]

# %%
test[predictors]
# Out:
#        Age   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...  STL  BLK  \
# 644     25  50  50  27.7  4.6  10.0  0.463  1.2  3.5  0.335  ...  0.7  0.7
# 645     28  36   7  23.5  2.9   6.8  0.424  1.5  4.1  0.369  ...  0.8  0.1
# 646     21  32   2   5.0  0.8   1.8  0.431  0.3  0.8  0.375  ...  0.1  0.3
# 647     29  65  19  21.9  1.8   4.8  0.381  1.2  3.3  0.352  ...  1.2  0.2
# 648     27   4   0   3.0  0.0   0.8  0.000  0.0  0.5  0.000  ...  0.0  0.0
# ...    ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...  ...  ...
# 14265   32  68   1  24.8  3.7   9.0  0.412  2.4  6.3  0.375  ...  0.6  0.0
# 14266   24  20   0   6.1  0.8   1.8  0.457  0.1  0.3  0.167  ...  0.4  0.1
# 14267   34  63   1  21.6  4.2  10.0  0.420  1.7  4.4  0.381  ...  0.7  0.6
# 14268   21  37   1   7.3  1.0   2.1  0.474  0.1  0.1  0.600  ...  0.2  0.0
# 14269   25  23   9  15.6  1.9   3.9  0.478  0.6  1.7  0.350  ...  0.3  0.0
#
#        TOV   PF   PTS   W/L%   GB   PS/G   PA/G   SRS
# ...

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=0.1)
# fit the model with the best alpha
ridge_model.fit(train[predictors], train['Share'])
# Out:
# Ridge(alpha=0.1)

# %%
ridge_model.intercept_
# Out:
# 0.07919694516259126

# %%
ridge_model.coef_
# Out:
# array([ 3.63381623e-04,  9.14608478e-05, -6.23410236e-06, -4.19694729e-03,
#         1.78612847e-03,  4.39835422e-03, -1.22755806e-01,  7.46251665e-03,
#        -9.71435820e-03, -8.67545685e-03,  1.96365138e-02, -1.64330512e-02,
#         1.54145665e-03,  5.88082861e-02, -6.75938009e-03,  1.12194142e-02,
#        -4.58107798e-03,  1.95927954e-02,  3.14781668e-02, -2.43907035e-02,
#         7.49382206e-03,  1.25765643e-02,  1.06907908e-02, -9.44492500e-03,
#        -2.23658617e-03,  6.60175829e-03,  5.89914423e-02,  2.73018064e-04,
#        -3.63454753e-04, -4.74405947e-04, -7.65891824e-04])

# %%
predictions=ridge_model.predict(test[predictors])

# %%
predictions=pd.DataFrame(predictions,columns=['RR Predictions'],index=test.index)

# %%
ridge_test_result_df=pd.concat([test[['Player','Share']],predictions],axis=1)
ridge_test_result_df
# Out:
#                        Player  Share  RR Predictions
# 644              Aaron Gordon    0.0        0.014711
# 645             Austin Rivers    0.0       -0.013424
# 646                   Bol Bol    0.0        0.002951
# 647          Facundo Campazzo    0.0       -0.002164
# 648          Greg Whittington    0.0        0.012644
# ...                       ...    ...             ...
# 14265             Patty Mills    0.0       -0.012661
# 14266  Quinndary Weatherspoon    0.0       -0.009936
# 14267                Rudy Gay    0.0        0.016151
# 14268               Tre Jones    0.0       -0.019061
# 14269              Trey Lyles    0.0       -0.006515
#
# [540 rows x 3 columns]

# %%
result_df=ridge_test_result_df.sort_values('Share',ascending=False)
result_df['Rank']=list(range(1,result_df.shape[0]+1))
result_df.head(10)
# Out:
#                       Player  Share  RR Predictions  Rank
# 655             Nikola Jokić  0.961        0.156606     1
# 8791             Joel Embiid  0.580        0.165357     2
# 3707           Stephen Curry  0.449        0.143874     3
# 10102  Giannis Antetokounmpo  0.345        0.207284     4
# 1403              Chris Paul  0.138        0.073942     5
# 11288            Luka Dončić  0.042        0.150937     6
# 7613          Damian Lillard  0.038        0.117679     7
# 3592           Julius Randle  0.020        0.089014     8
# 3587            Derrick Rose  0.010        0.034510     9
# 11649            Rudy Gobert  0.008        0.095343    10

# %%
result_df=result_df.sort_values('RR Predictions',ascending=False)
result_df['Pred Rank']=list(range(1,result_df.shape[0]+1))
result_df.head(50)
# Out:
#                         Player  Share  RR Predictions  Rank  Pred Rank
# 10102    Giannis Antetokounmpo  0.345        0.207284     4          1
# 8791               Joel Embiid  0.580        0.165357     2          2
# 655               Nikola Jokić  0.961        0.156606     1          3
# 11288              Luka Dončić  0.042        0.150937     6          4
# 3792              LeBron James  0.001        0.147538    15          5
# 3707             Stephen Curry  0.449        0.143874     3          6
# 4260              James Harden  0.001        0.141487    13          7
# 4263              Kevin Durant  0.000        0.141130   531          8
# 12088          Zion Williamson  0.000        0.130258   251          9
# 6211              Jimmy Butler  0.000        0.121239   442         10
# 3946         Russell Westbrook  0.005        0.119033    11         11
# 7613            Damian Lillard  0.038        0.117679     7         12
# ...

# %%
result_df[result_df['Player']=='Derrick Rose']
# Out:
#             Player  Share  RR Predictions  Rank  Pred Rank
# 3587  Derrick Rose   0.01         0.03451     9         73

# %%
from statistics import mean
def find_ap(combination):
    actual = combination.sort_values("Share", ascending=False).head(10)
    predicted = combination.sort_values("RR Predictions", ascending=False)
    ps = []
    found = 0
    seen = 1
    for index,row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found / seen)
        seen += 1

    return mean(ps)

# %%
find_ap(result_df)
# Out:
# 0.6444801293395381

# %%
def backtest(stats, model, years, predictors):
    aps = []
    all_predictions = []
    #year starts from 1996
    for year in years:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = model.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["RR Predictions"], index=test.index)
        combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return mean(aps), aps, pd.concat(all_predictions)

# %%
years=list(range(1990,2022))
mean_ap, aps, all_predictions = backtest(player_stats, ridge_model, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7705385915327243

# %%
from sklearn.ensemble import RandomForestRegressor
import pickle

rf = RandomForestRegressor(n_estimators=500, random_state=1, min_samples_split=5)
filename='RandomForest.sav'
pickle.dump(rf,open(filename,'wb'))

mean_ap, aps, all_predictions = backtest(player_stats, rf, years[28:], predictors )

# %%
mean_ap
# Out:
# 0.78038154156284
